# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Life Expectancy Data.csv')
df.head(10)
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
# 5  Afghanistan  2010  Developing              58.8            279.0
# 6  Afghanistan  2009  Developing              58.6            281.0
# 7  Afghanistan  2008  Developing              58.1            287.0
# 8  Afghanistan  2007  Developing              57.5            295.0
# 9  Afghanistan  2006  Developing              57.3            295.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# ...

# %%
df.tail()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 2933  Zimbabwe  2004  Developing              44.3            723.0
# 2934  Zimbabwe  2003  Developing              44.5            715.0
# 2935  Zimbabwe  2002  Developing              44.8             73.0
# 2936  Zimbabwe  2001  Developing              45.3            686.0
# 2937  Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 2933             27     4.36                     0.0         68.0        31
# 2934             26     4.06                     0.0          7.0       998
# 2935             25     4.43                     0.0         73.0       304
# 2936             25     1.72                     0.0         76.0       529
# 2937             24     1.68                     0.0         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# ...

# %%
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
df.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
""""
Adult Mortality" has 10 missing values.
"Hepatitis B" has 553 missing values.
"GDP" has 448 missing values.
"Schooling" has 163 missing values.
"""
# Out:
# '"\nAdult Mortality" has 10 missing values.\n"Hepatitis B" has 553 missing values.\n"GDP" has 448 missing values.\n"Schooling" has 163 missing values.\n'

# %%
"""
-Columns with missing values:
    Alcohol, Hepatitis B, BMI, Polio, Total expenditure, Diphtheria, GDP, Population, Income composition of resources, Schooling.
-Different data types
    (float64(16), int64(4), object(2))
-Wide range between means and maximum values
-Population in scientific notation

Exploration Routes:

*Disease Trends by Year (Global vs. Regions):
-Healthcare expenditure percentage vs. disease trends and GDP per country.
-Explore the relationship between income composition and disease trends (Does a higher quality of life reduce diseases?).
*Schooling and Its Relationship with Diseases/Life Expectancy:
-Investigate how education levels affect diseases and life expectancy.
*GDP vs. Life Expectancy:
-Examine the relationship between GDP per capita and life expectancy.
 *Group analysis by: Continent and development status
"""
# Out:
# '\n-Columns with missing values:\n    Alcohol, Hepatitis B, BMI, Polio, Total expenditure, Diphtheria, GDP, Population, Income composition of resources, Schooling.\n-Different data types\n    (float64(16), int64(4), object(2))\n-Wide range between means and maximum values\n-Population in scientific notation\n\nExploration Routes:\n\n*Disease Trends by Year (Global vs. Regions):\n-Healthcare expenditure percentage vs. disease trends and GDP per country.\n-Explore the relationship between income composition and disease trends (Does a higher quality of life reduce diseases?).\n*Schooling and Its Relationship with Diseases/Life Expectancy:\n-Investigate how education levels affect diseases and life expectancy.\n*GDP vs. Life Expectancy:\n-Examine the relationship between GDP per capita and life expectancy.\n *Group analysis by: Continent and development status\n'

# %%
# Getting the relevant columns we want to use for our findings
relevant_cols = [
    'Country',
    'Year',
    'Status',
    'Hepatitis B',
    "Polio",
    'Diphtheria',
    'under-five deaths',
    'percentage expenditure',
    'GDP',
    'Schooling',
    'Population',
    "Life expectancy"
]

# %%
# creating a new df called df_relevant with relevant cols
# causes an error because our relevant_cols has col names that don't exist
#df_relevant = df[relevant_cols]

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
df.columns.str.strip()
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles', 'BMI', 'under-five deaths', 'Polio', 'Total expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness  1-19 years',
#        'thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
# stripping column names without whitespace
df = df.rename(columns={'Life expectancy ':'Life expectancy', 'under-five deaths ':'under-five deaths','Diphtheria ':'Diphtheria'})
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths', 'Polio', 'Total expenditure',
#        'Diphtheria', ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years',
#        ' thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
# now we can create a new df called df_relevant with relevant cols
df_relevant = df[relevant_cols]
df_relevant
# Out:
#           Country  Year      Status  Hepatitis B  Polio  Diphtheria  \
# 0     Afghanistan  2015  Developing         65.0    6.0        65.0
# 1     Afghanistan  2014  Developing         62.0   58.0        62.0
# 2     Afghanistan  2013  Developing         64.0   62.0        64.0
# 3     Afghanistan  2012  Developing         67.0   67.0        67.0
# 4     Afghanistan  2011  Developing         68.0   68.0        68.0
# ...           ...   ...         ...          ...    ...         ...
# 2933     Zimbabwe  2004  Developing         68.0   67.0        65.0
# 2934     Zimbabwe  2003  Developing          7.0    7.0        68.0
# 2935     Zimbabwe  2002  Developing         73.0   73.0        71.0
# 2936     Zimbabwe  2001  Developing         76.0   76.0        75.0
# 2937     Zimbabwe  2000  Developing         79.0   78.0        78.0
#
#       under-five deaths  percentage expenditure         GDP  Schooling  \
# 0                    83               71.279624  584.259210       10.1
# ...

# %%
df_relevant.describe()
# Out:
#               Year  Hepatitis B        Polio   Diphtheria  under-five deaths  \
# count  2938.000000  2385.000000  2919.000000  2919.000000        2938.000000
# mean   2007.518720    80.940461    82.550188    82.324084          42.035739
# std       4.613841    25.070016    23.428046    23.716912         160.445548
# min    2000.000000     1.000000     3.000000     2.000000           0.000000
# 25%    2004.000000    77.000000    78.000000    78.000000           0.000000
# 50%    2008.000000    92.000000    93.000000    93.000000           4.000000
# 75%    2012.000000    97.000000    97.000000    97.000000          28.000000
# max    2015.000000    99.000000    99.000000    99.000000        2500.000000
#
#        percentage expenditure            GDP    Schooling    Population  \
# count             2938.000000    2490.000000  2775.000000  2.286000e+03
# mean               738.251295    7483.158469    11.992793  1.275338e+07
# ...

# %%
"""    
-There is a wide range between the minimum and maximum values for Life expectancy.
-Population is displayed in scientific notation.
-The mean for under-five deaths is highly skewed upwards (mean = 42, median = 4).
-At least one country in the dataset has 0 years of schooling.

"""
# Out:
# '    \n-There is a wide range between the minimum and maximum values for Life expectancy.\n-Population is displayed in scientific notation.\n-The mean for under-five deaths is highly skewed upwards (mean = 42, median = 4).\n-At least one country in the dataset has 0 years of schooling.\n\n'

# %%
df_relevant.describe(include='object')
# Out:
#             Country      Status
# count          2938        2938
# unique          193           2
# top     Afghanistan  Developing
# freq             16        2426

# %%
df_relevant['Status'].value_counts()
# Out:
# Status
# Developing    2426
# Developed      512
# Name: count, dtype: int64

# %%
#There are 193 unique countries in the dataset, categorized into two statuses: 'Developed' and 'Developing'. 
# The majority of the records belong to developing countries, with 2426 entries classified as 'Developing' and 512 as 'Developed'

# %%
# Feature Engineer column to group countries by Region
# country-by-continent.json src: https://github.com/samayo/country-json/blob/master/src/country-by-continent.json

import json
with open('country-by-continent.json') as file:
    country_continent_converter = json.load(file)

# %%
print(country_continent_converter)
# Out:
# [{'country': 'Afghanistan', 'continent': 'Asia'}, {'country': 'Albania', 'continent': 'Europe'}, {'country': 'Algeria', 'continent': 'Africa'}, {'country': 'American Samoa', 'continent': 'Oceania'}, {'country': 'Andorra', 'continent': 'Europe'}, {'country': 'Angola', 'continent': 'Africa'}, {'country': 'Anguilla', 'continent': 'North America'}, {'country': 'Antarctica', 'continent': 'Antarctica'}, {'country': 'Antigua and Barbuda', 'continent': 'North America'}, {'country': 'Argentina', 'continent': 'South America'}, {'country': 'Armenia', 'continent': 'Asia'}, {'country': 'Aruba', 'continent': 'North America'}, {'country': 'Australia', 'continent': 'Oceania'}, {'country': 'Austria', 'continent': 'Europe'}, {'country': 'Azerbaijan', 'continent': 'Asia'}, {'country': 'Bahamas', 'continent': 'North America'}, {'country': 'Bahrain', 'continent': 'Asia'}, {'country': 'Bangladesh', 'continent': 'Asia'}, {'country': 'Barbados', 'continent': 'North America'}, {'country': 'Belarus', 'contine
# ...

# %%
type(country_continent_converter)
# Out:
# list

# %%
country_continent_converter[0]
# Out:
# {'country': 'Afghanistan', 'continent': 'Asia'}

# %%
country_continent_converter[0]["country"]
# Out:
# 'Afghanistan'

# %%
country_continent_converter[0]["continent"]
# Out:
# 'Asia'

# %%
# writing a for-loop to find the continent related to the country `Afghanistan`
for country_continent_dict in country_continent_converter:
    if 'Afghanistan' == country_continent_dict["country"]:
        print(country_continent_dict["continent"])
# Out:
# Asia

# %%
"""
for country in df_relevant['Country']:
    for country_continent_dict in country_continent_converter:
        if country_continent_dict == country_continent_dict["country"]:
            print(country_continent_dict["continent"])
"""
# Out:
# '\nfor country in df_relevant[\'Country\']:\n    for country_continent_dict in country_continent_converter:\n        if country_continent_dict == country_continent_dict["country"]:\n            print(country_continent_dict["continent"])\n'

# %%
# df_relevant['continent'] = [continent_dict["continent"] for continent_dict in country_continent_converter if df_relevant['Country'] == continent_dict["country"]][0]

# %%
# Create a mapper function to find continents for each country in the dataframe
def fixed_mapper(country_from_df):
    '''
    Takes in the country and outputs the continent of the country or N/A if continent not found
    '''
    for country_continent_dict in country_continent_converter:
        if country_from_df == country_continent_dict["country"]:
            return country_continent_dict["continent"]
        
    # if country_from_df loops through converter and doesn't find a continent
    # then return "N/A"
    return "N/A"

# %%
# def get_continent(country): 
#        return [continent_dict["continent"] for continent_dict in country_continent_converter if continent_dict["country"] == country] 


# df_relevant['continent_1'] = df_relevant['Country'].apply(get_continent)

# %%
# using mapper function to create new column "continent" inside df_relevant
#df_relevant["continent"] = df_relevant["Country"].map(fixed_mapper)


df_relevant.loc[:, "continent"] = df_relevant["Country"].map(fixed_mapper)
# Out:
# C:\Users\Elif Surucu\AppData\Local\Temp\ipykernel_21896\1841596260.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_relevant.loc[:, "continent"] = df_relevant["Country"].map(fixed_mapper)

# %%
df_relevant.head(10)
# Out:
#        Country  Year      Status  Hepatitis B  Polio  Diphtheria  \
# 0  Afghanistan  2015  Developing         65.0    6.0        65.0
# 1  Afghanistan  2014  Developing         62.0   58.0        62.0
# 2  Afghanistan  2013  Developing         64.0   62.0        64.0
# 3  Afghanistan  2012  Developing         67.0   67.0        67.0
# 4  Afghanistan  2011  Developing         68.0   68.0        68.0
# 5  Afghanistan  2010  Developing         66.0   66.0        66.0
# 6  Afghanistan  2009  Developing         63.0   63.0        63.0
# 7  Afghanistan  2008  Developing         64.0   64.0        64.0
# 8  Afghanistan  2007  Developing         63.0   63.0        63.0
# 9  Afghanistan  2006  Developing         64.0   58.0        58.0
#
#    under-five deaths  percentage expenditure         GDP  Schooling  \
# 0                 83               71.279624  584.259210       10.1
# 1                 86               73.523582  612.696514       10.0
# ...

# %%
df.tail()
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  \
# 2933  Zimbabwe  2004  Developing             44.3            723.0
# 2934  Zimbabwe  2003  Developing             44.5            715.0
# 2935  Zimbabwe  2002  Developing             44.8             73.0
# 2936  Zimbabwe  2001  Developing             45.3            686.0
# 2937  Zimbabwe  2000  Developing             46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 2933             27     4.36                     0.0         68.0        31
# 2934             26     4.06                     0.0          7.0       998
# 2935             25     4.43                     0.0         73.0       304
# 2936             25     1.72                     0.0         76.0       529
# 2937             24     1.68                     0.0         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria   HIV/AIDS         GDP  \
# ...

# %%
df_relevant['continent'].value_counts()
# Out:
# continent
# Africa           864
# Asia             752
# Europe           626
# North America    338
# South America    192
# Oceania          166
# Name: count, dtype: int64

# %%
# Finding all countries where continent wasn't found
test = df_relevant.loc[df_relevant['continent'] == 'N/A']
test['Country'].unique()
# Out:
# array([], dtype=object)

# %%
relabel_countries = {
    'Bolivia (Plurinational State of)': 'Bolivia',
    'Brunei Darussalam': 'Brunei',
       "Côte d'Ivoire": 'Ivory Coast',
       'Cabo Verde': 'Cape Verde',
       'Czechia': 'Czech Republic',
       "Democratic People's Republic of Korea": 'North Korea',
       'Democratic Republic of the Congo': 'The Democratic Republic of Congo',
       'Fiji': 'Fiji Islands',
       'Iran (Islamic Republic of)': 'Iran',
       "Lao People's Democratic Republic": 'Laos',
       'Micronesia (Federated States of)': 'Micronesia, Federated States of',
       'Republic of Korea': 'South Korea',
       'Republic of Moldova': 'Moldova',
       'Russian Federation': 'Russia',
       'Swaziland': 'Eswatini',
       'Syrian Arab Republic': 'Syria',
       'The former Yugoslav republic of Macedonia': 'North Macedonia',
       'Timor-Leste': 'East Timor',
       'United Kingdom of Great Britain and Northern Ireland': 'United Kingdom',
       'United Republic of Tanzania': 'Tanzania',
       'United States of America': 'United States',
       'Venezuela (Bolivarian Republic of)': 'Venezuela',
       'Viet Nam': 'Vietnam'
}

# %%
# Using a .replace to replace relevant country names
df_relevant.loc[:,'Country'] = df_relevant['Country'].replace(relabel_countries)

# %%
# Checking that relevant country names were changed
test = df_relevant.loc[df_relevant['continent'] == 'N/A']
test['Country'].unique()
# Out:
# array([], dtype=object)

# %%
# Finding continents again
df_relevant.loc[:,"continent"] = df_relevant["Country"].map(fixed_mapper)

# %%
# yay! all continents are found
test = df_relevant.loc[df_relevant['continent'] == 'N/A']
test['Country'].unique()
# Out:
# array([], dtype=object)

# %%
df_relevant.head()
# Out:
#        Country  Year      Status  Hepatitis B  Polio  Diphtheria  \
# 0  Afghanistan  2015  Developing         65.0    6.0        65.0
# 1  Afghanistan  2014  Developing         62.0   58.0        62.0
# 2  Afghanistan  2013  Developing         64.0   62.0        64.0
# 3  Afghanistan  2012  Developing         67.0   67.0        67.0
# 4  Afghanistan  2011  Developing         68.0   68.0        68.0
#
#    under-five deaths  percentage expenditure         GDP  Schooling  \
# 0                 83               71.279624  584.259210       10.1
# 1                 86               73.523582  612.696514       10.0
# 2                 89               73.219243  631.744976        9.9
# 3                 93               78.184215  669.959000        9.8
# 4                 97                7.097109   63.537231        9.5
#
#    Population  Life expectancy continent
# 0  33736494.0             65.0      Asia
# 1    327582.0             59.9      Asia
# ...

# %%
df_relevant.value_counts('Country')
# Out:
# Country
# Afghanistan              16
# Panama                   16
# New Zealand              16
# Nicaragua                16
# Niger                    16
#                          ..
# Cook Islands              1
# Palau                     1
# San Marino                1
# Dominica                  1
# Saint Kitts and Nevis     1
# Name: count, Length: 193, dtype: int64

# %%
df_relevant.loc[df_relevant["GDP"].isna()]["Country"].unique()
# Out:
# array(['Bahamas', 'Bolivia', 'Ivory Coast', 'Congo', 'Cook Islands',
#        'Czech Republic', 'North Korea',
#        'The Democratic Republic of Congo', 'Egypt', 'Eritrea', 'Gambia',
#        'Iran', 'Iraq', 'Kyrgyzstan', 'Laos', 'Libya',
#        'Micronesia, Federated States of', 'Monaco', 'Niue',
#        'Papua New Guinea', 'South Korea', 'Moldova',
#        'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'San Marino',
#        'Sao Tome and Principe', 'Slovakia', 'Somalia', 'South Sudan',
#        'Syria', 'North Macedonia', 'United Kingdom', 'Tanzania',
#        'United States', 'Venezuela', 'Vietnam', 'Yemen'], dtype=object)

# %%
df_relevant.loc[df_relevant["Population"].isna()]["Country"].unique()
# Out:
# array(['Antigua and Barbuda', 'Bahamas', 'Bahrain', 'Barbados', 'Bolivia',
#        'Brunei', 'Ivory Coast', 'Congo', 'Cook Islands', 'Cuba',
#        'Czech Republic', 'North Korea',
#        'The Democratic Republic of Congo', 'Dominica', 'Egypt', 'Eritrea',
#        'Gambia', 'Grenada', 'Iran', 'Kuwait', 'Kyrgyzstan', 'Laos',
#        'Libya', 'Marshall Islands', 'Micronesia, Federated States of',
#        'Monaco', 'Nauru', 'New Zealand', 'Niue', 'Oman', 'Qatar',
#        'South Korea', 'Moldova', 'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'San Marino', 'Saudi Arabia',
#        'Singapore', 'Slovakia', 'Somalia', 'North Macedonia',
#        'United Arab Emirates', 'United Kingdom', 'Tanzania',
#        'United States', 'Venezuela', 'Vietnam', 'Yemen'], dtype=object)

# %%
df_relevant["Year"].unique()
# Out:
# array([2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005,
#        2004, 2003, 2002, 2001, 2000], dtype=int64)

# %%
years = df_relevant["Year"].unique()
continents = df_relevant["continent"].unique()

# %%
# group by year and continent, get the sum of under-five deaths
under_five_deaths_by_cont_year = df_relevant.groupby(by=["continent", "Year"])["under-five deaths"].sum()
under_five_deaths_by_cont_year
# Out:
# continent      Year
# Africa         2000    4292
#                2001    4232
#                2002    4154
#                2003    4071
#                2004    3984
#                        ...
# South America  2011     129
#                2012     123
#                2013     120
#                2014     113
#                2015     111
# Name: under-five deaths, Length: 96, dtype: int64

# %%
"""
# getting y_axis for Africa under 5 deaths per year
y_axis_africa = []
for year in years:
    y_axis_africa.append(under_five_deaths_by_cont_year["Africa"][year])

# getting y_axis for Asia under 5 deaths per year
y_axis_asia = []
for year in years:
    y_axis_asia.append(under_five_deaths_by_cont_year["Asia"][year])
"""
# Out:
# '\n# getting y_axis for Africa under 5 deaths per year\ny_axis_africa = []\nfor year in years:\n    y_axis_africa.append(under_five_deaths_by_cont_year["Africa"][year])\n\n# getting y_axis for Asia under 5 deaths per year\ny_axis_asia = []\nfor year in years:\n    y_axis_asia.append(under_five_deaths_by_cont_year["Asia"][year])\n'

# %%
# Under-5 deaths per year by continent
# x-axis: year
# y-axis: under 5 deaths
# each continent would have its own line in the graph
# FOR TABLEAU: Under-5 deaths by continent + status

fig, ax = plt.subplots(figsize=(10, 5))

colors = ['blue', 'green', 'red', 'purple', 'orange', 'pink']

for i, continent in enumerate(continents):
    # for every continent, get the under five deaths for every year
    under_five_deaths_per_continent = [under_five_deaths_by_cont_year[continent][year] for year in years]

    # plot under five deaths for that continent
    ax.plot(years, under_five_deaths_per_continent, label=continent, color=colors[i], linestyle='-', marker='o')


ax.set_title('Under-5 Deaths per year per continent')
ax.set_xlabel('Year')
ax.set_ylabel('Under-5 Deaths')
ax.legend()
ax.grid(True)
plt.show()

# %%
# Manual way

"""
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(years, y_axis_africa, label='Africa', color='blue', linestyle='-', marker='o')
ax.plot(years, y_axis_asia, label='Asia', color='red', linestyle='-', marker='o')
ax.set_title('Line Plot')
ax.set_xlabel('Year')
ax.set_ylabel('Under-5 Deaths')
ax.legend()
ax.grid(True)
plt.show()
"""
# Out:
# "\nfig, ax = plt.subplots(figsize=(10, 5))\nax.plot(years, y_axis_africa, label='Africa', color='blue', linestyle='-', marker='o')\nax.plot(years, y_axis_asia, label='Asia', color='red', linestyle='-', marker='o')\nax.set_title('Line Plot')\nax.set_xlabel('Year')\nax.set_ylabel('Under-5 Deaths')\nax.legend()\nax.grid(True)\nplt.show()\n"

# %%
# next step: basically do the same thing but for adult mortality rates

# %%
"""- box plot of percentage expenditure per continent (goal: see the outliers to normalize the data even more)
    - What's the minimum amount they should be spending on health to lower deaths
- go back to immunization data for asia and africa and whether immunization helps to lower under 5 deaths
- education levels vs under 5 deaths (in asia / africa)
"""
# Out:
# "- box plot of percentage expenditure per continent (goal: see the outliers to normalize the data even more)\n    - What's the minimum amount they should be spending on health to lower deaths\n- go back to immunization data for asia and africa and whether immunization helps to lower under 5 deaths\n- education levels vs under 5 deaths (in asia / africa)\n"

# %%
 #box plot of percentage expenditure per continent (goal: see the outliers to normalize the data even more)

fig, ax = plt.subplots(figsize=(10, 5))

sns.boxplot(x='continent', y='percentage expenditure', data = df_relevant.loc[(df_relevant['continent'] =='Asia') & (df_relevant['Year'] == 2014)], ax=ax)


plt.title('Box Plot of Percentage Expenditure Per Continent')
plt.xlabel('continent')
plt.ylabel('percentage expenditure')
#plt.ylim(0,50)
plt.show()

# %%
df_2014 = df_relevant.loc[ (df_relevant['Year'] == 2014)]

df_2014['percentage expenditure'].value_counts()
# Out:
# percentage expenditure
# 0.000000       29
# 45.337887       1
# 8.523486        1
# 1491.703605     1
# 1040.278436     1
#                ..
# 941.756291      1
# 97.677946       1
# 2163.043414     1
# 789.276461      1
# 10.822595       1
# Name: count, Length: 155, dtype: int64

# %%
#df_asia_2014.loc[df_asia_2014['percentage expenditure'] == 0]

drop_index = df_2014.loc[df_2014['percentage expenditure'] == 0].index
df_2014 = df_2014.drop(drop_index)

df_2014
# Out:
#                   Country  Year      Status  Hepatitis B  Polio  Diphtheria  \
# 1             Afghanistan  2014  Developing         62.0   58.0        62.0
# 17                Albania  2014  Developing         98.0   98.0        98.0
# 33                Algeria  2014  Developing         95.0   95.0        95.0
# 49                 Angola  2014  Developing         64.0   68.0        64.0
# 65    Antigua and Barbuda  2014  Developing         99.0   96.0        99.0
# ...                   ...   ...         ...          ...    ...         ...
# 2811              Uruguay  2014  Developing         95.0   95.0        95.0
# 2827           Uzbekistan  2014  Developing         99.0   99.0        99.0
# 2843              Vanuatu  2014  Developing         64.0   65.0        64.0
# 2907               Zambia  2014  Developing         86.0   78.0        86.0
# 2923             Zimbabwe  2014  Developing         91.0   92.0        91.0
#
# ...

# %%
df_2014['percentage expenditure'].value_counts()
# Out:
# percentage expenditure
# 73.523582      1
# 166.191373     1
# 8.523486       1
# 1491.703605    1
# 1040.278436    1
#               ..
# 941.756291     1
# 97.677946      1
# 2163.043414    1
# 789.276461     1
# 10.822595      1
# Name: count, Length: 154, dtype: int64

# %%
median_expenditure_per_continent_2014 = df_2014.groupby(by=['continent'])['percentage expenditure'].median()

median_expenditure_per_continent_2014
# Out:
# continent
# Africa             59.487449
# Asia              181.908378
# Europe           1144.661902
# North America     473.123812
# Oceania           564.816704
# South America     704.570108
# Name: percentage expenditure, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10, 5))

colors = ['blue', 'green', 'red', 'purple', 'orange', 'pink']

continents = list(median_expenditure_per_continent_2014.keys())
expenditures = list((median_expenditure_per_continent_2014.values))

ax.bar(continents, expenditures, color = ['blue', 'green', 'red', 'purple', 'orange', 'pink'] )


ax.set_title('Median Percentage Expenditure per Continent(2014)')
ax.set_xlabel('Continent')
ax.set_ylabel('Median Percentage Expenditure')


plt.show()

# %%
""" 

Recommendation 1: Recommendation 1: Asia and Africa’s governments should raise healthcare subsidies more,
 ideally to match North America’s subsidization of 473% per capita in order to lower the amount of deaths in children under 5


*High healthcare costs: Countries with advanced medical systems or aging populations may spend heavily on healthcare,
leading to high health expenditures relative to GDP per capita.
Subsidies and support: Governments might heavily subsidize healthcare, 
leading to spending that exceeds the economic output per person.
Low GDP per capita: In some countries, a relatively low GDP per capita (e.g., in developing economies) 
can make health expenditure appear larger in percentage terms even if the actual expenditure is not high.

"""
# Out:
# ' \n\nRecommendation 1: Recommendation 1: Asia and Africa’s governments should raise healthcare subsidies more,\n ideally to match North America’s subsidization of 473% per capita in order to lower the amount of deaths in children under 5\n\n\n*High healthcare costs: Countries with advanced medical systems or aging populations may spend heavily on healthcare,\nleading to high health expenditures relative to GDP per capita.\nSubsidies and support: Governments might heavily subsidize healthcare, \nleading to spending that exceeds the economic output per person.\nLow GDP per capita: In some countries, a relatively low GDP per capita (e.g., in developing economies) \ncan make health expenditure appear larger in percentage terms even if the actual expenditure is not high.\n\n'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
# Compare vacinnaiton rate of each disease for children at 1 years 
print(f"Correlation Coefficient of Hepatitis B and deaths under 5 is {df_relevant['Hepatitis B'].corr(df_relevant['under-five deaths'])}")
print(f"Correlation Coefficient of Polio and deaths under 5 is {df_relevant['Polio'].corr(df_relevant['under-five deaths'])}")
print(f"Correlation Coefficient of Diphtheria and deaths under 5 is {df_relevant['Diphtheria'].corr(df_relevant['under-five deaths'])}")
# Out:
# Correlation Coefficient of Hepatitis B and deaths under 5 is -0.233126250822761
# Correlation Coefficient of Polio and deaths under 5 is -0.1887202129701154
# Correlation Coefficient of Diphtheria and deaths under 5 is -0.19566828756228097

# %%
hepatitis_by_cont_year = df_relevant.groupby(by=["continent", "Year"])["Hepatitis B"].median()
polio_by_cont_year = df_relevant.groupby(by=["continent", "Year"])["Polio"].median()
diphtheria_by_cont_year = df_relevant.groupby(by=["continent", "Year"])["Diphtheria"].median()

# %%
# Vacinnations per year by continent
# x-axis: year
# y-axis: Types of vaccines
# each continent would have its own line in the graph
# FOR TABLEAU: Under-5 deaths by continent + status

fig, ax = plt.subplots(figsize=(10, 5))


# for every continent, get the under five deaths for every year
immunization_rate_per_cont_hep = [hepatitis_by_cont_year['Asia'][year] for year in years]
immunization_rate_per_cont_pol = [polio_by_cont_year['Asia'][year] for year in years]
immunization_rate_per_cont_dip = [diphtheria_by_cont_year['Asia'][year] for year in years]



# plot under five deaths for that continent
ax.plot(years, immunization_rate_per_cont_hep, label='Hepatitis B', color='red', linestyle='-', marker='o')
ax.plot(years, immunization_rate_per_cont_pol, label='Polio', color='blue', linestyle='-', marker='o')
ax.plot(years, immunization_rate_per_cont_dip, label='Diphtheria', color='green', linestyle='-', marker='o')


ax.set_title('Immunization Rates per Year in Asia')
ax.set_xlabel('Year')
ax.set_ylabel('Vaccine Rate (%)')
ax.legend()
ax.grid(True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 5))


# for every continent, get the under five deaths for every year
immunization_rate_per_cont_hep = [hepatitis_by_cont_year['Africa'][year] for year in years]
immunization_rate_per_cont_pol = [polio_by_cont_year['Africa'][year] for year in years]
immunization_rate_per_cont_dip = [diphtheria_by_cont_year['Africa'][year] for year in years]



# plot under five deaths for that continent
ax.plot(years, immunization_rate_per_cont_hep, label='Hepatitis B', color='red', linestyle='-', marker='o')
ax.plot(years, immunization_rate_per_cont_pol, label='Polio', color='blue', linestyle='-', marker='o')
ax.plot(years, immunization_rate_per_cont_dip, label='Diphtheria', color='green', linestyle='-', marker='o')


ax.set_title('Immunization Rates per Year in Africa')
ax.set_xlabel('Year')
ax.set_ylabel('Vaccine Rate (%)')
ax.legend()
ax.grid(True)
plt.show()

# %% [markdown]
# Recommendation 2: Further research is need on the decrease in death count for children under 5 in Asia. This research may lead to measures that can be implemented in Africa to decrease child deaths.
#
# Potential causes of decrease in death count in Asia:
#   - Immunization rates of other common diseases in Asia
#   - Affects of population density on deaths of children under 5
#   - Cultural factors

# %%
# Rec 3: schooling vs under 5 deaths per continent

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
# Median schooling per continent vs life expectancy per continent 
df["Schooling"].corr(df["Life expectancy"])
# Out:
# 0.7519754627366979

# %%
df.loc[df["Life expectancy"].isna()]

# since there are only 10 null rows in life expectancy, we can drop these rows
# Out:
#                     Country  Year      Status  Life expectancy  \
# 624            Cook Islands  2013  Developing              NaN
# 769                Dominica  2013  Developing              NaN
# 1650       Marshall Islands  2013  Developing              NaN
# 1715                 Monaco  2013  Developing              NaN
# 1812                  Nauru  2013  Developing              NaN
# 1909                   Niue  2013  Developing              NaN
# 1958                  Palau  2013  Developing              NaN
# 2167  Saint Kitts and Nevis  2013  Developing              NaN
# 2216             San Marino  2013  Developing              NaN
# 2713                 Tuvalu  2013  Developing              NaN
#
#       Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 624               NaN              0     0.01                0.000000
# 769               NaN              0     0.01               11.419555
# ...

# %%
df.loc[df["Schooling"].isna()]

# there are approx. 10 countries that don't report schooling data, so we will drop these as well
# Out:
#                        Country  Year      Status  Life expectancy  \
# 432              Côte d'Ivoire  2015  Developing             53.3
# 433              Côte d'Ivoire  2014  Developing             52.8
# 434              Côte d'Ivoire  2013  Developing             52.3
# 435              Côte d'Ivoire  2012  Developing             52.0
# 436              Côte d'Ivoire  2011  Developing             51.7
# ...                        ...   ...         ...              ...
# 2805  United States of America  2004   Developed             77.5
# 2806  United States of America  2003   Developed             77.2
# 2807  United States of America  2002   Developed             77.0
# 2808  United States of America  2001   Developed             76.9
# 2809  United States of America  2000   Developed             76.8
#
#       Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 432             397.0             57      NaN                     0.0
# ...

# %%
# Dropping null values for schooling and life expectancy data and creating new df
df_schooling = df_relevant.dropna(subset=["Schooling", "Life expectancy"])
df_schooling
# Out:
#           Country  Year      Status  Hepatitis B  Polio  Diphtheria  \
# 0     Afghanistan  2015  Developing         65.0    6.0        65.0
# 1     Afghanistan  2014  Developing         62.0   58.0        62.0
# 2     Afghanistan  2013  Developing         64.0   62.0        64.0
# 3     Afghanistan  2012  Developing         67.0   67.0        67.0
# 4     Afghanistan  2011  Developing         68.0   68.0        68.0
# ...           ...   ...         ...          ...    ...         ...
# 2933     Zimbabwe  2004  Developing         68.0   67.0        65.0
# 2934     Zimbabwe  2003  Developing          7.0    7.0        68.0
# 2935     Zimbabwe  2002  Developing         73.0   73.0        71.0
# 2936     Zimbabwe  2001  Developing         76.0   76.0        75.0
# 2937     Zimbabwe  2000  Developing         79.0   78.0        78.0
#
#       under-five deaths  percentage expenditure         GDP  Schooling  \
# 0                    83               71.279624  584.259210       10.1
# ...

# %%
df_schooling["Life expectancy"].sort_values()
# Out:
# 1127    36.3
# 2312    39.0
# 2311    41.0
# 2309    41.5
# 2308    42.3
#         ...
# 241     89.0
# 1850    89.0
# 2513    89.0
# 2056    89.0
# 995     89.0
# Name: Life expectancy, Length: 2768, dtype: float64

# %%
min_life_expectancy = df_schooling["Life expectancy"].min()
max_life_expectancy = df_schooling["Life expectancy"].max()

# %%
min_schooling = df_schooling["Schooling"].min()
max_schooling = df_schooling["Schooling"].max()

# %%
x=3
row = x//2
print(f'row = {row}')
col = x%2
print(f'col = {col}')
# Out:
# row = 1
# col = 1

# %%
# Schooling vs life expectancy per continent
# x-axis: number of schooling years
# y-axis: Life expectancy age
# each continent would have its own line in the graph

fig, axs = plt.subplots(3, 2, figsize=(10, 12))

colors = ['blue', 'green', 'red', 'purple', 'orange', 'pink']

# for-loop to loop through continents
for i, continent in enumerate(continents):

    # use the mod and // to indicate row and col in the axis
    # get schooling and life expectancy data for each continent
    
    x_axis = df_schooling.loc[df_schooling["continent"] == continent]["Schooling"]
    y_axis = df_schooling.loc[df_schooling["continent"] == continent]["Life expectancy"]

    axs[i//2, i%2].scatter(x_axis, y_axis, color= colors[i], marker="o")

    # creating line of best fit
    coeffs = np.polyfit(x_axis, y_axis, 1)
    trend_line = np.polyval(coeffs, x_axis)
    axs[i//2, i%2].plot(x_axis, trend_line, color="black", linestyle="--", label='Trend Line')


    axs[i//2, i%2].set_title('Schooling vs Life Expectancy in ' + continent)
    axs[i//2, i%2].set_xlim(min_schooling - 1, max_schooling + 1)
    axs[i//2, i%2].set_ylim(min_life_expectancy - 5, max_life_expectancy + 5)

fig.text(0.5, 0.04, 'Years of Schooling', ha='center', fontsize=12)
fig.text(0.04, 0.5, 'Life Expectancy (Years)', va='center', rotation='vertical', fontsize=12)
plt.tight_layout(rect=[0.05, 0.05, 1, 0.95])

plt.show();

"""
# Asia
a[0,0]xs.scatter(df_schooling.loc[df_schooling["continent"] == "Asia"]["Schooling"], df_schooling.loc[df_schooling["continent"] == "Asia"]["Life expectancy"], color="red", marker="o")
axs[0,0].set_title('Schooling vs Life Expectancy in Asia')
axs[0,0].set_xlim(min_schooling - 1, max_schooling + 1)
axs[0,0].set_ylim(min_life_expectancy - 5, max_life_expectancy + 5)

# Africa
axs[0,1].scatter(df_schooling.loc[df_schooling["continent"] == "Africa"]["Schooling"], df_schooling.loc[df_schooling["continent"] == "Africa"]["Life expectancy"], color="red", marker="o")
axs[0,1].set_title('Schooling vs Life Expectancy in Africa')
axs[0,1].set_xlim(min_schooling -1, max_schooling + 1)
axs[0,1].set_ylim(min_life_expectancy - 5, max_life_expectancy + 5)
"""
# Out:
# '\n# Asia\na[0,0]xs.scatter(df_schooling.loc[df_schooling["continent"] == "Asia"]["Schooling"], df_schooling.loc[df_schooling["continent"] == "Asia"]["Life expectancy"], color="red", marker="o")\naxs[0,0].set_title(\'Schooling vs Life Expectancy in Asia\')\naxs[0,0].set_xlim(min_schooling - 1, max_schooling + 1)\naxs[0,0].set_ylim(min_life_expectancy - 5, max_life_expectancy + 5)\n\n# Africa\naxs[0,1].scatter(df_schooling.loc[df_schooling["continent"] == "Africa"]["Schooling"], df_schooling.loc[df_schooling["continent"] == "Africa"]["Life expectancy"], color="red", marker="o")\naxs[0,1].set_title(\'Schooling vs Life Expectancy in Africa\')\naxs[0,1].set_xlim(min_schooling -1, max_schooling + 1)\naxs[0,1].set_ylim(min_life_expectancy - 5, max_life_expectancy + 5)\n'

# %% [markdown]
# Recommendation 3:
# We see a very clear positive correlation between years of school and life expectancy in all continents.
# Our recommendation would be to keep kids in school for as long as possible, as the longer they are in school, the higher their life expectancy is.

# %%
df_relevant.to_csv('Life_expectancy_clean.csv', index=False)
